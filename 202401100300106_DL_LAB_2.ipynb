# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))
def sigmoid_derivative(a):
  return a*(1-a)

# %%
np.random.seed(0)
X=np.random.uniform(0.05,0.45,(100,1))
y =2*X

# %%
input_size=1
hidden_size=10
output_size=1
learning_rate=0.5
epochs=5000
W1=np.random.randn(input_size,hidden_size)*0.1
b1=np.zeros((1,hidden_size))
W2=np.random.randn(hidden_size,output_size)*0.1
b2=np.zeros((1,output_size))

# %%
loss_history=[]
for epoch in range(epochs):
  z1=np.dot(X,W1)+b1
  a1=sigmoid(z1)

  z2=np.dot(a1,W2)+b2
  y_hat=sigmoid(z2)
  loss=np.mean((y-y_hat)**2)
  loss_history.append(loss)

  d_output=(y_hat-y)*sigmoid_derivative(y_hat)
  dW2=np.dot(a1.T,d_output)
  db2=np.sum(d_output,axis=0,keepdims=True)

  d_hidden=np.dot(d_output,W2.T)*sigmoid_derivative(a1)
  dW1=np.dot(X.T,d_hidden)
  db1=np.sum(d_hidden,axis=0,keepdims=True)

  W2-=learning_rate*dW2
  b2-=learning_rate*db2
  W1-=learning_rate*dW1
  b1-=learning_rate*db1

  if epoch%1000==0:
      print("Epoch:",epoch,"Loss:",loss)
# Out:
# Epoch: 0 Loss: 0.01706646011901937
# Epoch: 1000 Loss: 0.017001162085889962
# Epoch: 2000 Loss: 0.016972986813794614
# Epoch: 3000 Loss: 0.016961984545221985
# Epoch: 4000 Loss: 0.016958449109418395

# %%
plt.plot(loss_history)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.show()

# %%
test=np.array([[0.1],[0.25],[0.4]])

z1=np.dot(test,W1)+b1
a1=sigmoid(z1)
z2=np.dot(a1,W2)+b2
pred=sigmoid(z2)
# Out:
# Predictions:
# [[0.05089267]
#  [0.40478134]
#  [0.64908421]]
